# %% [markdown]
# <a href="https://colab.research.google.com/github/albertmontiel2020-arch/Notebook_Agro_2026_1/blob/main/Noteboook_Semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA: Entra ancho y alto de la madera en metros
ancho = input("ingresa en ancho de la ventana en metros")
ancho = float(ancho)
alto = input("ingresa el alto de la ventana en metros")
alto = float(alto)

# PROCESO: Calcula longitud de la madera (lm) en pies
# y el area del vidrio en metros cuadrados
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)

# SALIDA: Sale la longitud de la madera en pies
# Y el area del vidrio en metros cuadadrados
print (" la longitud de la madera es ", lm, "pies de longitud")
print (" EL area del vidrio es ", av, "metros cuadrados")
# Out:
# ingresa en ancho de la ventana en metros1
# ingresa el alto de la ventana en metros2
#  la longitud de la madera es  19.5 pies de longitud
#  EL area del vidrio es  4.0 metros cuadrados
